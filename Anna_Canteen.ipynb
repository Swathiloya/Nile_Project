# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel(r'C:\Users\hp\Desktop\anna_canteen (1).xlsx',sheet_name='Sheet6')
df
# Out:
#    No_of_ Customer No_of_ Food Delivery_ Units No_of_ Anna_ Canteens  \
# 0              300                  Gow_Down-1             Canteen-1
# 1              300                         NaN             Canteen-2
# 2              300                         NaN             Canteen-3
# 3              300                         NaN             Canteen-4
# 4              300                         NaN             Canteen-5
# 5              300                  Gow_Down-2             Canteen-6
# 6              300                         NaN             Canteen-7
# 7              300                         NaN             Canteen-8
# 8              300                         NaN             Canteen-9
#
#    Total_ Available_ Food Plates  No_of _Plates Consumed  \
# 0                            320                     300
# 1                            320                     300
# 2                            320                     300
# ...

# %%
df1=pd.DataFrame(df)
df1
# Out:
#    No_of_ Customer No_of_ Food Delivery_ Units No_of_ Anna_ Canteens  \
# 0              300                  Gow_Down-1             Canteen-1
# 1              300                         NaN             Canteen-2
# 2              300                         NaN             Canteen-3
# 3              300                         NaN             Canteen-4
# 4              300                         NaN             Canteen-5
# 5              300                  Gow_Down-2             Canteen-6
# 6              300                         NaN             Canteen-7
# 7              300                         NaN             Canteen-8
# 8              300                         NaN             Canteen-9
#
#    Total_ Available_ Food Plates  No_of _Plates Consumed  \
# 0                            320                     300
# 1                            320                     300
# 2                            320                     300
# ...

# %%
df.head()
# Out:
#    No_of_ Customer No_of_ Food Delivery_ Units No_of_ Anna_ Canteens  \
# 0              300                  Gow_Down-1             Canteen-1
# 1              300                         NaN             Canteen-2
# 2              300                         NaN             Canteen-3
# 3              300                         NaN             Canteen-4
# 4              300                         NaN             Canteen-5
#
#    Total_ Available_ Food Plates  No_of _Plates Consumed  \
# 0                            320                     300
# 1                            320                     300
# 2                            320                     300
# 3                            320                     300
# 4                            320                     300
#
#    No_of_ Feedbacks Received  Rating Food weight_GowDown  \
# 0                        120       4               270kg
# 1                        160       4               270kg
# ...

# %%
df.tail()
# Out:
#    No_of_ Customer No_of_ Food Delivery_ Units No_of_ Anna_ Canteens  \
# 4              300                         NaN             Canteen-5
# 5              300                  Gow_Down-2             Canteen-6
# 6              300                         NaN             Canteen-7
# 7              300                         NaN             Canteen-8
# 8              300                         NaN             Canteen-9
#
#    Total_ Available_ Food Plates  No_of _Plates Consumed  \
# 4                            320                     300
# 5                            320                     270
# 6                            320                     300
# 7                            320                     300
# 8                            320                     300
#
#    No_of_ Feedbacks Received  Rating Food weight_GowDown  \
# 4                        180       3               270kg
# 5                        250       4               270kg
# ...

# %%
df.dtypes
# Out:
# No_of_ Customer                   int64
# No_of_ Food Delivery_ Units      object
# No_of_ Anna_ Canteens            object
# Total_ Available_ Food Plates     int64
# No_of _Plates Consumed            int64
# No_of_ Feedbacks Received         int64
# Rating                            int64
# Food weight_GowDown              object
# Food weight Anna_Canteen         object
# No_of_ Donations                  int64
# Total _Donation Amount            int64
# No_of _Employs                    int64
# Total _Generated_ Tokens          int64
# dtype: object

# %%
df.columns
# Out:
# Index(['No_of_ Customer', 'No_of_ Food Delivery_ Units',
#        'No_of_ Anna_ Canteens', 'Total_ Available_ Food Plates',
#        'No_of _Plates Consumed', 'No_of_ Feedbacks Received', 'Rating',
#        'Food weight_GowDown', 'Food weight Anna_Canteen', 'No_of_ Donations',
#        'Total _Donation Amount', 'No_of _Employs', 'Total _Generated_ Tokens'],
#       dtype='object')

# %%
df.shape
# Out:
# (9, 13)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   No_of_ Customer                9 non-null      int64
#  1   No_of_ Food Delivery_ Units    2 non-null      object
#  2   No_of_ Anna_ Canteens          9 non-null      object
#  3   Total_ Available_ Food Plates  9 non-null      int64
#  4   No_of _Plates Consumed         9 non-null      int64
#  5   No_of_ Feedbacks Received      9 non-null      int64
#  6   Rating                         9 non-null      int64
#  7   Food weight_GowDown            9 non-null      object
#  8   Food weight Anna_Canteen       9 non-null      object
#  9   No_of_ Donations               9 non-null      int64
#  10  Total _Donation Amount         9 non-null      int64
#  11  No_of _Employs                 9 non-null      int64
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.plot(kind='bar',
        x='No_of_ Anna_ Canteens',
        y='Total _Donation Amount',
        color='green')

plt.title('anna_canteen_donations')


plt.show()

# %%
df.plot(kind='scatter',
        x='No_of _Plates Consumed',
        y='No_of_ Anna_ Canteens',
        color='red'
     )


plt.title('About food plates')


plt.show()

# %%
df.set_index('No_of_ Anna_ Canteens', inplace=True)

# Pie chart
df.plot(kind='pie', y='Rating',autopct='%1.1f%%', startangle=150,legend=False)
plt.title('canteen Ratings')
plt.show()

# %%
df.set_index('No_of_ Customer', inplace=True)

# Pie chart
df.plot(kind='pie', y='Rating',autopct='%1.1f%%', startangle=150,legend=False)
plt.title('canteen Ratings')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
import math #needed for definition of pi

df.plot(x,y)
df.xlabel('No_of _Employs')
df.ylabel('No_of_ Anna_ Canteens')
df.title('anna canteen')
df.show()
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\pandas\plotting\_core.py:886: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if "sort_columns" in itertools.chain(args, kwargs.keys()):
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 6
#       4 x = np.arange(0, math.pi*2, 0.05)
#       5 y = np.tan(x)
# ----> 6 df.plot(x,y)
#       7 df.xlabel('No_of _Employs')
#       8 df.ylabel('No_of_ Anna_ Canteens')
#
# File ~\anaconda3\lib\site-packages\pandas\plotting\_core.py:965, in PlotAccessor.__call__(self, *args, **kwargs)
#     963 if is_integer(x) and not data.columns.holds_integer():
#     964     x = data_cols[x]
# --> 965 elif not isinstance(data[x], ABCSeries):
#     966     raise ValueError("x must be a label or position")
#     967 data = data.set_index(x)
#
# ...
