# %%
import pandas
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel(r'C:\Users\hp\Downloads\Anna_canteen_edited.xlsx')
df
# Out:
#    Muncipal_Corporation No_Of_Food_delivery_units  \
# 0          Corporation1                  Gowdown1
# 1          Corporation1                  Gowdown1
# 2          Corporation1                  Gowdown1
# 3          Corporation1                  Gowdown2
# 4          Corporation1                  Gowdown2
# ..                  ...                       ...
# 94         Corporation9                  Gowdown1
# 95         Corporation9                  Gowdown2
# 96         Corporation9                  Gowdown2
# 97         Corporation9                  Gowdown2
# 98         Corporation9                  Gowdown2
#
#    Quantity_delivery_from_each_Gowdown  No_of_employees No.of_anna_canteen  \
# 0                                600kg               15           Canteen1
# 1                                600kg               15           Canteen2
# 2                                600kg               15           Canteen3
# ...

# %%
df1=pd.DataFrame(df)
df1
# Out:
#    Muncipal_Corporation No_Of_Food_delivery_units  \
# 0          Corporation1                  Gowdown1
# 1          Corporation1                  Gowdown1
# 2          Corporation1                  Gowdown1
# 3          Corporation1                  Gowdown2
# 4          Corporation1                  Gowdown2
# ..                  ...                       ...
# 94         Corporation9                  Gowdown1
# 95         Corporation9                  Gowdown2
# 96         Corporation9                  Gowdown2
# 97         Corporation9                  Gowdown2
# 98         Corporation9                  Gowdown2
#
#    Quantity_delivery_from_each_Gowdown  No_of_employees No.of_anna_canteen  \
# 0                                600kg               15           Canteen1
# 1                                600kg               15           Canteen2
# 2                                600kg               15           Canteen3
# ...

# %%
df.head()
# Out:
#   Muncipal_Corporation No_Of_Food_delivery_units  \
# 0         Corporation1                  Gowdown1
# 1         Corporation1                  Gowdown1
# 2         Corporation1                  Gowdown1
# 3         Corporation1                  Gowdown2
# 4         Corporation1                  Gowdown2
#
#   Quantity_delivery_from_each_Gowdown  No_of_employees No.of_anna_canteen  \
# 0                               600kg               15           Canteen1
# 1                               600kg               15           Canteen2
# 2                               600kg               15           Canteen3
# 3                               750kg               25           Canteen1
# 4                               750kg               25           Canteen2
#
#   Preparation_time_for_each_canteen Food_temperature  No_of_Items  Total_cost  \
# 0                              1hrs            135°F            7       50000
# ...

# %%
df.tail()
# Out:
#    Muncipal_Corporation No_Of_Food_delivery_units  \
# 94         Corporation9                  Gowdown1
# 95         Corporation9                  Gowdown2
# 96         Corporation9                  Gowdown2
# 97         Corporation9                  Gowdown2
# 98         Corporation9                  Gowdown2
#
#    Quantity_delivery_from_each_Gowdown  No_of_employees No.of_anna_canteen  \
# 94                               600kg               23           Canteen4
# 95                               650kg               25           Canteen1
# 96                               650kg               25           Canteen2
# 97                               650kg               25           Canteen3
# 98                               650kg               25           Canteen4
#
#    Preparation_time_for_each_canteen Food_temperature  No_of_Items  \
# 94                              2hrs            135°F            7
# 95                              2hrs            135°F            7
# ...

# %%
df.columns
# Out:
# Index(['Muncipal_Corporation', 'No_Of_Food_delivery_units',
#        'Quantity_delivery_from_each_Gowdown', 'No_of_employees',
#        'No.of_anna_canteen', 'Preparation_time_for_each_canteen',
#        'Food_temperature', 'No_of_Items', 'Total_cost', 'No.of_customers',
#        'Total_available_food_plates', 'No.of_plates_consumed',
#        'No.of_feedbacks_received', 'No.of_positive_feedbacks',
#        'No.of_negative_feedbacks', 'Food_weight_at_annacanteen',
#        'No.of_donations', 'Total_tokens_generated'],
#       dtype='object')

# %%
df.shape
# Out:
# (99, 18)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=99, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Muncipal_Corporation                 99 non-null     object
#  1   No_Of_Food_delivery_units            99 non-null     object
#  2   Quantity_delivery_from_each_Gowdown  99 non-null     object
#  3   No_of_employees                      99 non-null     int64
#  4   No.of_anna_canteen                   99 non-null     object
#  5   Preparation_time_for_each_canteen    99 non-null     object
#  6   Food_temperature                     99 non-null     object
#  7   No_of_Items                          99 non-null     int64
#  8   Total_cost                           99 non-null     int64
#  9   No.of_customers                      99 non-null     int64
#  10  Total_available_food_plates          99 non-null     int64
# ...

# %%
df.dtypes
# Out:
# Muncipal_Corporation                   object
# No_Of_Food_delivery_units              object
# Quantity_delivery_from_each_Gowdown    object
# No_of_employees                         int64
# No.of_anna_canteen                     object
# Preparation_time_for_each_canteen      object
# Food_temperature                       object
# No_of_Items                             int64
# Total_cost                              int64
# No.of_customers                         int64
# Total_available_food_plates             int64
# No.of_plates_consumed                   int64
# No.of_feedbacks_received                int64
# No.of_positive_feedbacks                int64
# No.of_negative_feedbacks                int64
# Food_weight_at_annacanteen             object
# No.of_donations                         int64
# Total_tokens_generated                  int64
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.plot(kind='bar',
        x='No.of_customers',
        y='No.of_donations',
        color='green',)
        
plt.title('Anna_Canteen') 



plt.show()

# %%
df.plot(kind='scatter',
        x='Muncipal_Corporation',
        y='No.of_anna_canteen',
        color='blue'
     )


plt.title('Muncipal_Corporation')


plt.show()

# %%
 df.set_index('Muncipal_Corporation', inplace=True)

# Pie chart
df.plot(kind='pie', y='No.of_donations',autopct='%1.1f%%', startangle=150,legend=False)
plt.title('Anna Canteen')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
import math #needed for definition of pi
x = np.arange(0, math.pi*2, 0.05)
y = np.tan(x)
plt.plot(x,y)
plt.xlabel('No.of_plates_consumed')
plt.ylabel('No.of_customers')
plt.title('canteen ratings')
plt.show()

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# # create 2D array of student details
# stdData = [['S260', 'M', 130, 123, 46],
#        ['S280', 'M', 120, 134, 82],
#        ['S300', 'F', 140, 114, 77],
#        ['S400', 'M', 130, 136, 73],
#        ['S150', 'F', 130, 107, 56],
#        ['S265', 'F', 120, 121, 80],
#        ['S172', 'M', 140, 113, 76],
#        ['S168', 'F', 150, 123, 95],
#        ['S269', 'F', 140, 112, 78],
#        ['S172', 'M', 150, 100,60] ]
# creating the dataframe from the above data
df = pd.DataFrame(stdData, columns = ['No_of_Items', 'Total_available_food_plates','No.of_plates_consumed', 'No.of_donations','Total_tokens_generated'] )
df.hist()# create histogram for the numeric data(Age, Height,Marks)
plt.show() #displaying the plot
