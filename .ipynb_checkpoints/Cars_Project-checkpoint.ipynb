# %%
import pandas 
import pandas as pd
df=pd.read_excel(r"C:\swathi\Swathi_Car_Mahindra_Benz_Audi.xlsx")
df
# Out:
#                 CRA_NAME     BRAND       PRICE               EMI FUEL_TYPE  \
# 0  XUV700 AX3 D MT 5 STR  Mahindra   15.12Lakh      28,780/month    Diesel
# 1         BOLERO NEO N10  Mahindra  10.57 Lakh      20,119/month    Diesel
# 2        XUV700 AX 7 STR  Mahindra  23.25 Lakh  41,846/starts at    Petrol
# 3   XUV700 AX 5 MT 5 STR  Mahindra  18.65 Lakh  33,566/starts at    Diesel
# 4     XUV700 MX MT 5 STR  Mahindra   15.2 Lakh  27,357/starts at    Petrol
# 5    Scorpio Z8 AT 7 STR  Mahindra  20.75 Lakh  37,346/starts at    Petrol
# 6   XUV700 AX 3 MT 5 STR  Mahindra     16 Lakh  28,797/starts at    Petrol
# 7     XUV700 MX MT 5 STR  Mahindra   14.9 Lakh  26,817/starts at    Diesel
# 8              BOLERO N8   Mhindra   9.25 Lakh  16,648/starts at    Diesel
# 9          XUV300 1.5 W6   Mhindra   9.75 Lakh  17,548/starts at    Diesel
#
#   MAKE YEAR  KM DRIVEN   REG YEAR ENGINE CAPACITY  \
# 0      2022  28,671 km  feb _2023         2184 cc
# ...

# %%
df.shape
# Out:
# (10, 14)

# %%
df.columns
# Out:
# Index(['CRA_NAME', 'BRAND', 'PRICE', 'EMI', 'FUEL_TYPE', 'MAKE YEAR',
#        'KM DRIVEN', 'REG YEAR', 'ENGINE CAPACITY', 'INSURANCE', 'REG NUMBER',
#        'SPARE KEY', 'OWNER SHIP', 'COLOR'],
#       dtype='object')

# %%
df.head
# Out:
# <bound method NDFrame.head of                 CRA_NAME     BRAND       PRICE               EMI FUEL_TYPE  \
# 0  XUV700 AX3 D MT 5 STR  Mahindra   15.12Lakh      28,780/month    Diesel
# 1         BOLERO NEO N10  Mahindra  10.57 Lakh      20,119/month    Diesel
# 2        XUV700 AX 7 STR  Mahindra  23.25 Lakh  41,846/starts at    Petrol
# 3   XUV700 AX 5 MT 5 STR  Mahindra  18.65 Lakh  33,566/starts at    Diesel
# 4     XUV700 MX MT 5 STR  Mahindra   15.2 Lakh  27,357/starts at    Petrol
# 5    Scorpio Z8 AT 7 STR  Mahindra  20.75 Lakh  37,346/starts at    Petrol
# 6   XUV700 AX 3 MT 5 STR  Mahindra     16 Lakh  28,797/starts at    Petrol
# 7     XUV700 MX MT 5 STR  Mahindra   14.9 Lakh  26,817/starts at    Diesel
# 8              BOLERO N8   Mhindra   9.25 Lakh  16,648/starts at    Diesel
# 9          XUV300 1.5 W6   Mhindra   9.75 Lakh  17,548/starts at    Diesel
#
#   MAKE YEAR  KM DRIVEN   REG YEAR ENGINE CAPACITY  \
# 0      2022  28,671 km  feb _2023         2184 cc
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                 CRA_NAME     BRAND       PRICE               EMI FUEL_TYPE  \
# 0  XUV700 AX3 D MT 5 STR  Mahindra   15.12Lakh      28,780/month    Diesel
# 1         BOLERO NEO N10  Mahindra  10.57 Lakh      20,119/month    Diesel
# 2        XUV700 AX 7 STR  Mahindra  23.25 Lakh  41,846/starts at    Petrol
# 3   XUV700 AX 5 MT 5 STR  Mahindra  18.65 Lakh  33,566/starts at    Diesel
# 4     XUV700 MX MT 5 STR  Mahindra   15.2 Lakh  27,357/starts at    Petrol
# 5    Scorpio Z8 AT 7 STR  Mahindra  20.75 Lakh  37,346/starts at    Petrol
# 6   XUV700 AX 3 MT 5 STR  Mahindra     16 Lakh  28,797/starts at    Petrol
# 7     XUV700 MX MT 5 STR  Mahindra   14.9 Lakh  26,817/starts at    Diesel
# 8              BOLERO N8   Mhindra   9.25 Lakh  16,648/starts at    Diesel
# 9          XUV300 1.5 W6   Mhindra   9.75 Lakh  17,548/starts at    Diesel
#
#   MAKE YEAR  KM DRIVEN   REG YEAR ENGINE CAPACITY  \
# 0      2022  28,671 km  feb _2023         2184 cc
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                 CRA_NAME     BRAND       PRICE               EMI FUEL_TYPE  \
# 0  XUV700 AX3 D MT 5 STR  Mahindra   15.12Lakh      28,780/month    Diesel
# 1         BOLERO NEO N10  Mahindra  10.57 Lakh      20,119/month    Diesel
# 2        XUV700 AX 7 STR  Mahindra  23.25 Lakh  41,846/starts at    Petrol
# 3   XUV700 AX 5 MT 5 STR  Mahindra  18.65 Lakh  33,566/starts at    Diesel
# 4     XUV700 MX MT 5 STR  Mahindra   15.2 Lakh  27,357/starts at    Petrol
# 5    Scorpio Z8 AT 7 STR  Mahindra  20.75 Lakh  37,346/starts at    Petrol
# 6   XUV700 AX 3 MT 5 STR  Mahindra     16 Lakh  28,797/starts at    Petrol
# 7     XUV700 MX MT 5 STR  Mahindra   14.9 Lakh  26,817/starts at    Diesel
# 8              BOLERO N8   Mhindra   9.25 Lakh  16,648/starts at    Diesel
# 9          XUV300 1.5 W6   Mhindra   9.75 Lakh  17,548/starts at    Diesel
#
#   MAKE YEAR  KM DRIVEN   REG YEAR ENGINE CAPACITY  \
# 0      2022  28,671 km  feb _2023         2184 cc
# ...

# %%
df.dtypes
# Out:
# CRA_NAME           object
# BRAND              object
# PRICE              object
# EMI                object
# FUEL_TYPE          object
# MAKE YEAR          object
# KM DRIVEN          object
# REG YEAR           object
# ENGINE CAPACITY    object
# INSURANCE          object
# REG NUMBER         object
# SPARE KEY          object
# OWNER SHIP         object
# COLOR              object
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas 
import pandas as pd
df=pd.read_excel(r"C:\swathi\Swathi_Car_Mahindra_Benz_Audi.xlsx",sheet_name="Benz")
df
# Out:
#                             CRA_NAME BRAND       PRICE                 EMI  \
# 0              Benz GL-Class 350 CDI  Benz   31.9 Lakh  57,414  starts at
# 1               Benz S-Class 320 CDI  Benz     20 Lakh       Not Available
# 2  MG Astor Savvy 1.3 Turbo AT S Red  Benz     16 Lakh    28,797 starts at
# 3              MG AstorSuper 1.5 CVT  Benz   13.9 Lakh    25,017 starts at
# 4             MG Astor Super 1.5 CVT  Benz  13.95 Lakh    25,107 starts at
# 5                 Benz SLK-CLASS 350  Benz  39.75 Lakh       Not Available
# 6                     Benz GLE 250 d  Benz   35.9 Lakh   64,614  starts at
# 7                     Benz GLE 250 d  Benz     41 Lakh    73,793 starts at
# 8                     Benz GLE 250 d  Benz   42.5 Lakh    76,492 starts at
# 9                     BENZ GLE 350 d  Benz   39.5 Lakh   71,093  starts at
#
#        FUEL_TYPE  MAKE YEAR    KM DRIVEN  REG YEAR  ENGINE CAPACITY  \
# 0         Diesel 2015-06-01    80,660 km       NaN              NaN
# ...

# %%
df.shape
# Out:
# (10, 14)

# %%
df.columns
# Out:
# Index(['CRA_NAME', 'BRAND', 'PRICE', 'EMI', 'FUEL_TYPE', 'MAKE YEAR',
#        'KM DRIVEN', 'REG YEAR', 'ENGINE CAPACITY', 'INSURANCE', 'REG NUMBER',
#        'SPARE KEY', 'OWNER SHIP', 'COLOR'],
#       dtype='object')

# %%
df.head
# Out:
# <bound method NDFrame.head of                             CRA_NAME BRAND       PRICE                 EMI  \
# 0              Benz GL-Class 350 CDI  Benz   31.9 Lakh  57,414  starts at
# 1               Benz S-Class 320 CDI  Benz     20 Lakh       Not Available
# 2  MG Astor Savvy 1.3 Turbo AT S Red  Benz     16 Lakh    28,797 starts at
# 3              MG AstorSuper 1.5 CVT  Benz   13.9 Lakh    25,017 starts at
# 4             MG Astor Super 1.5 CVT  Benz  13.95 Lakh    25,107 starts at
# 5                 Benz SLK-CLASS 350  Benz  39.75 Lakh       Not Available
# 6                     Benz GLE 250 d  Benz   35.9 Lakh   64,614  starts at
# 7                     Benz GLE 250 d  Benz     41 Lakh    73,793 starts at
# 8                     Benz GLE 250 d  Benz   42.5 Lakh    76,492 starts at
# 9                     BENZ GLE 350 d  Benz   39.5 Lakh   71,093  starts at
#
#        FUEL_TYPE  MAKE YEAR    KM DRIVEN  REG YEAR  ENGINE CAPACITY  \
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                             CRA_NAME BRAND       PRICE                 EMI  \
# 0              Benz GL-Class 350 CDI  Benz   31.9 Lakh  57,414  starts at
# 1               Benz S-Class 320 CDI  Benz     20 Lakh       Not Available
# 2  MG Astor Savvy 1.3 Turbo AT S Red  Benz     16 Lakh    28,797 starts at
# 3              MG AstorSuper 1.5 CVT  Benz   13.9 Lakh    25,017 starts at
# 4             MG Astor Super 1.5 CVT  Benz  13.95 Lakh    25,107 starts at
# 5                 Benz SLK-CLASS 350  Benz  39.75 Lakh       Not Available
# 6                     Benz GLE 250 d  Benz   35.9 Lakh   64,614  starts at
# 7                     Benz GLE 250 d  Benz     41 Lakh    73,793 starts at
# 8                     Benz GLE 250 d  Benz   42.5 Lakh    76,492 starts at
# 9                     BENZ GLE 350 d  Benz   39.5 Lakh   71,093  starts at
#
#        FUEL_TYPE  MAKE YEAR    KM DRIVEN  REG YEAR  ENGINE CAPACITY  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                             CRA_NAME BRAND       PRICE                 EMI  \
# 0              Benz GL-Class 350 CDI  Benz   31.9 Lakh  57,414  starts at
# 1               Benz S-Class 320 CDI  Benz     20 Lakh       Not Available
# 2  MG Astor Savvy 1.3 Turbo AT S Red  Benz     16 Lakh    28,797 starts at
# 3              MG AstorSuper 1.5 CVT  Benz   13.9 Lakh    25,017 starts at
# 4             MG Astor Super 1.5 CVT  Benz  13.95 Lakh    25,107 starts at
# 5                 Benz SLK-CLASS 350  Benz  39.75 Lakh       Not Available
# 6                     Benz GLE 250 d  Benz   35.9 Lakh   64,614  starts at
# 7                     Benz GLE 250 d  Benz     41 Lakh    73,793 starts at
# 8                     Benz GLE 250 d  Benz   42.5 Lakh    76,492 starts at
# 9                     BENZ GLE 350 d  Benz   39.5 Lakh   71,093  starts at
#
#        FUEL_TYPE  MAKE YEAR    KM DRIVEN  REG YEAR  ENGINE CAPACITY  \
# ...

# %%
df.dtypes
# Out:
# CRA_NAME                   object
# BRAND                      object
# PRICE                      object
# EMI                        object
# FUEL_TYPE                  object
# MAKE YEAR          datetime64[ns]
# KM DRIVEN                  object
# REG YEAR                  float64
# ENGINE CAPACITY           float64
# INSURANCE                  object
# REG NUMBER                float64
# SPARE KEY                 float64
# OWNER SHIP                 object
# COLOR                      object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas 
import pandas as pd
df=pd.read_excel(r"C:\swathi\Swathi_Car_Mahindra_Benz_Audi.xlsx",sheet_name="Audi")
df
# Out:
#                                  CRA_NAME BRAND       PRICE  \
# 0            Audi A4 35 TDI Premium Sport  Audi  13.9  Lakh
# 1          Audi Q3 35 TDI Premium+Sunroof  Audi   16.5 Lakh
# 2    Audi Q3 2.O TDI quattro Premium Plus  Audi  15.95 Lakh
# 3          Audi A4 35 TDI Premium Sunroof  Audi  11.95 Lakh
# 4  Audi A3 35 TDI  Premium Plus + Sunroof  Audi     12 Lakh
# 5             Audi A4 35 TDI Premium Plus  Audi     27 Lakh
# 6         Audi A4 30 TFSI Technology Pack  Audi  23.75 Lakh
# 7                   Audi A4 2.0 TDI Sline  Audi      9 Lakh
# 8                   Audi A4 2.0 TDI Sline  Audi    9.5 Lakh
# 9                   Audi A4 2.0 TDI Sline  Audi     10 Lakh
#
#                  EMI Not Available  MAKE YEAR    KM DRIVEN  REG YEAR  \
# 0   25017  starts at        Diesel 2015-06-01    57,211 km       NaN
# 1   29,697 starts at        Diesel 2015-06-01  1,07,900 km       NaN
# 2    28707 starts at        Diesel 2014-06-01    89,000 km       NaN
# ...

# %%
df.shape
# Out:
# (10, 14)

# %%
df.columns
# Out:
# Index(['CRA_NAME', 'BRAND', 'PRICE', 'EMI', 'Not Available', 'MAKE YEAR',
#        'KM DRIVEN', 'REG YEAR', 'ENGINE CAPACITY', 'INSURANCE', 'REG NUMBER',
#        'SPARE KEY', 'OWNER SHIP', 'COLOR'],
#       dtype='object')

# %%
df.head
# Out:
# <bound method NDFrame.head of                                  CRA_NAME BRAND       PRICE  \
# 0            Audi A4 35 TDI Premium Sport  Audi  13.9  Lakh
# 1          Audi Q3 35 TDI Premium+Sunroof  Audi   16.5 Lakh
# 2    Audi Q3 2.O TDI quattro Premium Plus  Audi  15.95 Lakh
# 3          Audi A4 35 TDI Premium Sunroof  Audi  11.95 Lakh
# 4  Audi A3 35 TDI  Premium Plus + Sunroof  Audi     12 Lakh
# 5             Audi A4 35 TDI Premium Plus  Audi     27 Lakh
# 6         Audi A4 30 TFSI Technology Pack  Audi  23.75 Lakh
# 7                   Audi A4 2.0 TDI Sline  Audi      9 Lakh
# 8                   Audi A4 2.0 TDI Sline  Audi    9.5 Lakh
# 9                   Audi A4 2.0 TDI Sline  Audi     10 Lakh
#
#                  EMI Not Available  MAKE YEAR    KM DRIVEN  REG YEAR  \
# 0   25017  starts at        Diesel 2015-06-01    57,211 km       NaN
# 1   29,697 starts at        Diesel 2015-06-01  1,07,900 km       NaN
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                                  CRA_NAME BRAND       PRICE  \
# 0            Audi A4 35 TDI Premium Sport  Audi  13.9  Lakh
# 1          Audi Q3 35 TDI Premium+Sunroof  Audi   16.5 Lakh
# 2    Audi Q3 2.O TDI quattro Premium Plus  Audi  15.95 Lakh
# 3          Audi A4 35 TDI Premium Sunroof  Audi  11.95 Lakh
# 4  Audi A3 35 TDI  Premium Plus + Sunroof  Audi     12 Lakh
# 5             Audi A4 35 TDI Premium Plus  Audi     27 Lakh
# 6         Audi A4 30 TFSI Technology Pack  Audi  23.75 Lakh
# 7                   Audi A4 2.0 TDI Sline  Audi      9 Lakh
# 8                   Audi A4 2.0 TDI Sline  Audi    9.5 Lakh
# 9                   Audi A4 2.0 TDI Sline  Audi     10 Lakh
#
#                  EMI Not Available  MAKE YEAR    KM DRIVEN  REG YEAR  \
# 0   25017  starts at        Diesel 2015-06-01    57,211 km       NaN
# 1   29,697 starts at        Diesel 2015-06-01  1,07,900 km       NaN
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                  CRA_NAME BRAND       PRICE  \
# 0            Audi A4 35 TDI Premium Sport  Audi  13.9  Lakh
# 1          Audi Q3 35 TDI Premium+Sunroof  Audi   16.5 Lakh
# 2    Audi Q3 2.O TDI quattro Premium Plus  Audi  15.95 Lakh
# 3          Audi A4 35 TDI Premium Sunroof  Audi  11.95 Lakh
# 4  Audi A3 35 TDI  Premium Plus + Sunroof  Audi     12 Lakh
# 5             Audi A4 35 TDI Premium Plus  Audi     27 Lakh
# 6         Audi A4 30 TFSI Technology Pack  Audi  23.75 Lakh
# 7                   Audi A4 2.0 TDI Sline  Audi      9 Lakh
# 8                   Audi A4 2.0 TDI Sline  Audi    9.5 Lakh
# 9                   Audi A4 2.0 TDI Sline  Audi     10 Lakh
#
#                  EMI Not Available  MAKE YEAR    KM DRIVEN  REG YEAR  \
# 0   25017  starts at        Diesel 2015-06-01    57,211 km       NaN
# 1   29,697 starts at        Diesel 2015-06-01  1,07,900 km       NaN
# ...

# %%
df.dtypes
# Out:
# CRA_NAME                   object
# BRAND                      object
# PRICE                      object
# EMI                        object
# Not Available              object
# MAKE YEAR          datetime64[ns]
# KM DRIVEN                  object
# REG YEAR                  float64
# ENGINE CAPACITY           float64
# INSURANCE                  object
# REG NUMBER                float64
# SPARE KEY                 float64
# OWNER SHIP                 object
# COLOR                      object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
