# %%
 mart="relince_mart"
cust_name="prasanna"
prod="veg"

purchase_amount=1000
sub_veg_amount=500
sub_groc_amount=250
sub_food_amount=250

if mart=="relince_mart":
    if cust_name=="prasanna":
        if prod=="veg":
            discount=0.30
            after_discount=sub_veg_amount*discount
            veg_after=sub_veg_amount-after_discount
            print("after discount",veg_after)
        elif prod=="groc":
            discount=0.10
            after_discount=sub_groc_amount*discount
            groc_after=sub_groc_amount-after_discount
            print("after discount",groc_after)
        elif prod=="food":
            discount=0.05
            after_discount=sub_food_amount*discount
            food_after=sub_food_amount-after_discount
            print("after discount",food_after)
        else:
            print("no available product")
        
    elif cust_name=="shaheena":
        if prod=="veg":
            discount=0.40
            after_discount=sub_veg_amount*discount
            veg_after=sub_veg_amount-after_discount
            print("after discount",veg_after)
        elif prod=="groc":
            discount=0.30
            after_discount=sub_groc_amount*discount
            groc_after=sub_groc_amount-after_discount
            print("after discount",groc_after)
        elif prod=="food":
            discount=0.25
            after_discount=sub_food_amount*discount
            food_after=sub_food_amount-after_discount
            print("after discount",food_after)
        else:
            print("no available product")
        
    elif cust_name=="swathi":
        if prod=="veg":
            discount=0.50
            after_discount=sub_veg_amount*discount
            veg_after=sub_veg_amount-after_discount
            print("after discount",veg_after)
        elif prod=="gorc":
            discount=0.20
            after_discount=sub_groc_amount*discount
            groc_after=sub_groc_amount-after_discount
            print("after discount",groc_after)
        elif prod=="food":
            discount=0.15
            after_discount=sub_food_amount*discount
            food_after=sub_food_amount-after_discount
            print("after discount",food_after)
        else:
            print("no available product")

    else:
        print("no customer")
    
elif mart=="jio_mart":
    if cust_name=="prasanna":
        if prod=="veg":
            discount=0.20
            after_discount=sub_veg_amount*discount
            veg_after=sub_veg_amount-after_discount
            print("after discount",veg_after)
        elif prod=="groc":
            discount=0.10
            after_discount=sub_groc_amount*discount
            groc_after=sub_groc_amount-after_discount
            print("after discount",groc_after)
        elif prod=="food":
            discount=0.05
            after_discount=sub_food_amount*discount
            food_after=sub_food_amount-after_discount
            print("after discount",food_after)
        else:
            print("no available product") 
        
    elif cust_name=="shaheena":
        if prod=="veg":
            discount=0.50
            after_discount=sub_veg_amount*discount
            veg_after=sub_veg_amount-after_discount
            print("after discount",veg_after)
        elif prod=="groc":
            discount=0.30
            after_discount=sub_groc_amount*discount
            groc_after=sub_groc_amount-after_discount
            print("after discount",groc_after)
        elif prod=="food":
            discount=0.35
            after_discount=sub_food_amount*discount
            food_after=sub_food_amount-afterdiscount
            print("after discount",food_after)
        else:
            print("no available product") 
        
    elif cust_name=="swathi":
        if prod=="veg":
            discount=0.40
            after_discount=sub_veg_amount*discount
            veg_after=sub_veg_amount-after_discount
            print("after discount",veg_after)
        elif prod=="groc":
            discount=0.40
            after_discount=sub_groc_amount*discount
            groc_after=sub_groc_amount-after_discount
            print("after discount",groc_after)      
        elif prod=="food":
            discount=0.25
            after_discount=sub_food_amount*discount
            food_after=sub_food_amount-after_discount
            print("after discount",food_after)
        else:
            print("no available product") 
    else:
        print("no available customer")
else:
    print("no mart available")
# Out:
# after discount 350.0

# %%
mart_type=["reliance","jio"]
cust_type=["prasanna","shaheena,","bujji","swathi"]
prod_cat=["vegitable","groceries","fooditems"]
overall_amount=[500,250,250]

# %%
for mart in mart_type:
    if mart=="reliance":
        print("***************this is mart reliance")
        for cust in cust_type:
            if cust=="prasanna":
                print("------------------>this is customer prasanna ")
                for product in prod_cat:
                    print("$$$$$$$$$$$$$$$$$$$$this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.30
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.10
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.05
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)  
    elif mart=="jio":
        print("***************this is mart jio")
        for cust in cust_type:
            if cust=="prasanna":
                print("------------------>this is customer prasanna ")
                for product in prod_cat:
                    print("$$$$$$$$$$$$$$$$$$$$this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.20
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.10
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.05
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)
# Out:
# ***************this is mart reliance
# ------------------>this is customer prasanna
# $$$$$$$$$$$$$$$$$$$$this is product vegitable
# after vegitable discount amount 350.0
# $$$$$$$$$$$$$$$$$$$$this is product groceries
# after groceries discount amount 225.0
# $$$$$$$$$$$$$$$$$$$$this is product fooditems
# after food discount amount 237.5
# ***************this is mart jio
# ------------------>this is customer prasanna
# $$$$$$$$$$$$$$$$$$$$this is product vegitable
# after vegitable discount amount 400.0
# $$$$$$$$$$$$$$$$$$$$this is product groceries
# after groceries discount amount 225.0
# $$$$$$$$$$$$$$$$$$$$this is product fooditems
# after food discount amount 237.5

# %%
mart_type=["reliance","jio"]
cust_type=["prasanna","shaheena","bujji","swathi"]
prod_cat=["vegitable","groceries","fooditems"]
overall_amount=[500,250,250]

# %%
for mart in mart_type:
    if mart=="reliance":
        print("------------------>this is mart reliance")
        for cust in cust_type:
            if cust=="prasanna":
                print("********************this is customer prasanna")
                for product in prod_cat:
                    print("##################this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.30
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.10
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.05
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)  
            elif cust=="shaheena":
                print("*********************this is customer shaheena")
                for product in prod_cat:
                    print("##################this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.40
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.30
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.25
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)  
                        
            elif cust=="bujji":
                print("*********************this is customer bujji")
                for product in prod_cat:
                    print("##################this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.30
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.10
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.50
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)  
            elif cust=="swathi":
                print("***********************this is customer swathi")
                for product in prod_cat:
                    print("####################this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.50
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.20
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.15
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)  

    elif mart=="jio":
        print("------------------>this is mart jio")
        for cust in cust_type:
            if cust=="prasanna":
                print("********************this is customer prasanna")
                for product in prod_cat:
                    print("##################this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.20
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.10
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.05
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)  
            elif cust=="shaheena":
                print("*********************this is customer shaheena")
                for product in prod_cat:
                    print("##################this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.50
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.30
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.35
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)  
                        
            elif cust=="bujji":
                print("*********************this is customer bujji")
                for product in prod_cat:
                    print("##################this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.30
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.10
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.50
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)  
            elif cust=="swathi":
                print("***********************this is customer swathi")
                for product in prod_cat:
                    print("####################this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.40
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.40
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.25
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)
# Out:
# ------------------>this is mart reliance
# ********************this is customer prasanna
# ##################this is product vegitable
# after vegitable discount amount 350.0
# ##################this is product groceries
# after groceries discount amount 225.0
# ##################this is product fooditems
# after food discount amount 237.5
# *********************this is customer shaheena
# ##################this is product vegitable
# after vegitable discount amount 300.0
# ##################this is product groceries
# after groceries discount amount 175.0
# ##################this is product fooditems
# after food discount amount 187.5
# *********************this is customer bujji
# ##################this is product vegitable
# after vegitable discount amount 350.0
# ##################this is product groceries
# after groceries discount amount 225.0
# ##################this is product fooditems
# after food discount amount 125.0
# ***********************this is customer swathi
# ...

# %%
mart_type=["reliance","jio"]
cust_type=["prasanna","shaheena","swathi"]
prod_cat=["vegitable","groceries","fooditems"]
overall_amount=[500,250,250]

# %%
for mart in mart_type:
    if mart=="reliance":
        print("------------------->this is mart reliance")
        for cust in cust_type:
            if cust=="prasanna":
                print("*****************this is customer prasanna ")
                for product in prod_cat:
                    print("$$$$$$$$$$$$$$$$$$$$$$this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.30
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.10
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.05
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)
                    else:
                        print("no product available")
            elif cust=="shaheena":
                print("*******************this is customer shaheena ")
                for product in prod_cat:
                    print("$$$$$$$$$$$$$$$$$$this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.40
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.30
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.25
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)
                    else:
                        print("no product available")
            elif cust=="swathi":
                print("*******************this is customer swathi")
                for product in prod_cat:
                    print("$$$$$$$$$$$$$$$$$$this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.50
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.20
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.15
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)
                    else:
                        print("no product available")

    elif mart=="jio":
        print("------------------->this is mart",mart)
        for cust in cust_type:
            if cust=="prasanna":
                print("*****************this is customer prasanna ")
                for product in prod_cat:
                    print("$$$$$$$$$$$$$$$$$$$$$$this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.20
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.10
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.05
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)
                    else:
                        print("no product available")
            elif cust=="shaheena":
                print("*******************this is customer shaheena ")
                for product in prod_cat:
                    print("$$$$$$$$$$$$$$$$$$this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.50
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.30
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.35
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)
                    else:
                        print("no product available")
            elif cust=="swathi":
                print("*******************this is customer swathi")
                for product in prod_cat:
                    print("$$$$$$$$$$$$$$$$$$this is product",product)
                    if product=="vegitable":
                        discount=overall_amount[0]*.40
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after vegitable discount amount", afterdiscount_veg)
                    elif product=="groceries":
                        discount=overall_amount[1]*.40
                        afterdiscount_groc=overall_amount[1]-discount
                        print("after groceries discount amount", afterdiscount_groc)
                    elif product=="fooditems":
                        discount=overall_amount[2]*.25
                        afterdiscount_food=overall_amount[2]-discount
                        print("after food discount amount", afterdiscount_food)
                    else:
                        print("no product available"
# Out:
# ------------------->this is mart reliance
# *****************this is customer prasanna
# $$$$$$$$$$$$$$$$$$$$$$this is product vegitable
# after vegitable discount amount 350.0
# $$$$$$$$$$$$$$$$$$$$$$this is product groceries
# after groceries discount amount 225.0
# $$$$$$$$$$$$$$$$$$$$$$this is product fooditems
# after food discount amount 237.5
# *******************this is customer shaheena
# $$$$$$$$$$$$$$$$$$this is product vegitable
# after vegitable discount amount 300.0
# $$$$$$$$$$$$$$$$$$this is product groceries
# after groceries discount amount 175.0
# $$$$$$$$$$$$$$$$$$this is product fooditems
# after food discount amount 187.5
# *******************this is customer swathi
# $$$$$$$$$$$$$$$$$$this is product vegitable
# after vegitable discount amount 250.0
# $$$$$$$$$$$$$$$$$$this is product groceries
# after groceries discount amount 200.0
# $$$$$$$$$$$$$$$$$$this is product fooditems
# after food discount amount 212.5
# ------------------->this is mart jio
# ...

# %%
mart_type=["reliance","jio"]
cust_type=["prasanna","shaheena","swathi"]
prod_cat=["vegitable","groceries","fooditems"]
overall_amount=[500,250,250]

# %%
for mart in mart_type:
    if mart=="reliance":
        print("this is reliance mart") 
        for cust in cust_type:
            if cust=="prasanna":
                print("this is customer prasanna")
                for product in prod_cat:
                    print("this is product",product)
                    if product=="vegitable": 
                        discount=overall_amount[0]*.30
                        afterdiscount_veg=overall_amount[0]-discount
                        print("after veg discount amount",afterdiscount_veg)
# Out:
# this is reliance mart
# this is customer prasanna
# this is product vegitable
# after veg discount amount 350.0
# this is product groceries
# this is product fooditems

# %%
mart_type=["reliance","jio"]
for bujji in mart_type:
    print("this is my mart",bujji)
# Out:
# this is my mart reliance
# this is my mart jio

# %%
mart_type=["reliance","jio"]
cust_type=["prasanna","shaheena","swathi"]
for bujji in mart_type:
    print("this is my mart",bujji)
    for cust in cust_type:
        print("my customers",cust)
# Out:
# this is my mart reliance
# my customers prasanna
# my customers shaheena
# my customers swathi
# this is my mart jio
# my customers prasanna
# my customers shaheena
# my customers swathi

# %%
mart_type=["reliance","jio"]
cust_type=["prasanna","shaheena","swathi","bujji"]
prod_cat=["vegitable","groceries","fooditems"]
for mart in mart_type:
    if mart=="reliance":
        print("this is reliance mart",mart)
        for cust in cust_type:
            if cust=="prasanna":
                print("this is my name",cust)
            for prod in prod_cat:
                print("this is my item",prod)
# Out:
# this is reliance mart reliance
# this is my name prasanna
# this is my item vegitable
# this is my item groceries
# this is my item fooditems
# this is my item vegitable
# this is my item groceries
# this is my item fooditems
# this is my item vegitable
# this is my item groceries
# this is my item fooditems
# this is my item vegitable
# this is my item groceries
# this is my item fooditems
