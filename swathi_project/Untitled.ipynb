# %%
import pandas
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel(r'C:\Users\hp\Downloads\26-07-2024.xlsx')
df
# Out:
#   Muncipal_Corporation No_Of_Food_delivery_units  \
# 0         Corporation1                  Gowdown1
# 1         Corporation1                  Gowdown1
# 2         Corporation1                  Gowdown1
# 3         Corporation1                  Gowdown2
# 4         Corporation1                  Gowdown2
# 5         Corporation1                  Gowdown2
# 6         Corporation1                  Gowdown2
# 7         Corporation1                  Gowdown3
# 8         Corporation1                  Gowdown3
#
#   Quantity_delivery_from_each_Gowdown  No_of_employees No.of_anna_canteen  \
# 0                               600kg               15           Canteen1
# 1                               600kg               15           Canteen2
# 2                               600kg               15           Canteen3
# 3                               750kg               25           Canteen1
# 4                               750kg               25           Canteen2
# ...

# %%
df1=pd.DataFrame(df)
df1
# Out:
#   Muncipal_Corporation No_Of_Food_delivery_units  \
# 0         Corporation1                  Gowdown1
# 1         Corporation1                  Gowdown1
# 2         Corporation1                  Gowdown1
# 3         Corporation1                  Gowdown2
# 4         Corporation1                  Gowdown2
# 5         Corporation1                  Gowdown2
# 6         Corporation1                  Gowdown2
# 7         Corporation1                  Gowdown3
# 8         Corporation1                  Gowdown3
#
#   Quantity_delivery_from_each_Gowdown  No_of_employees No.of_anna_canteen  \
# 0                               600kg               15           Canteen1
# 1                               600kg               15           Canteen2
# 2                               600kg               15           Canteen3
# 3                               750kg               25           Canteen1
# 4                               750kg               25           Canteen2
# ...

# %%
df.head()
# Out:
#   Muncipal_Corporation No_Of_Food_delivery_units  \
# 0         Corporation1                  Gowdown1
# 1         Corporation1                  Gowdown1
# 2         Corporation1                  Gowdown1
# 3         Corporation1                  Gowdown2
# 4         Corporation1                  Gowdown2
#
#   Quantity_delivery_from_each_Gowdown  No_of_employees No.of_anna_canteen  \
# 0                               600kg               15           Canteen1
# 1                               600kg               15           Canteen2
# 2                               600kg               15           Canteen3
# 3                               750kg               25           Canteen1
# 4                               750kg               25           Canteen2
#
#   Preparation_time_for_each_canteen Food_temperature  No_of_Items  Total_cost  \
# 0                              1hrs            135°F            7       50000
# ...
