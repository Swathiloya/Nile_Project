# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\swathi\Swathi_Car_Mahindra_Benz_Audi.xlsx")
df
# Out:
#                 CRA_NAME     BRAND       PRICE               EMI FUEL_TYPE  \
# 0  XUV700 AX3 D MT 5 STR  Mahindra   15.12Lakh      28,780/month    Diesel
# 1         BOLERO NEO N10  Mahindra  10.57 Lakh      20,119/month    Diesel
# 2        XUV700 AX 7 STR  Mahindra  23.25 Lakh  41,846/starts at    Petrol
# 3   XUV700 AX 5 MT 5 STR  Mahindra  18.65 Lakh  33,566/starts at    Diesel
# 4     XUV700 MX MT 5 STR  Mahindra   15.2 Lakh  27,357/starts at    Petrol
# 5    Scorpio Z8 AT 7 STR  Mahindra  20.75 Lakh  37,346/starts at    Petrol
# 6   XUV700 AX 3 MT 5 STR  Mahindra     16 Lakh  28,797/starts at    Petrol
# 7     XUV700 MX MT 5 STR  Mahindra   14.9 Lakh  26,817/starts at    Diesel
# 8              BOLERO N8   Mhindra   9.25 Lakh  16,648/starts at    Diesel
# 9          XUV300 1.5 W6   Mhindra   9.75 Lakh  17,548/starts at    Diesel
#
#   MAKE YEAR  KM DRIVEN   REG YEAR ENGINE CAPACITY  \
# 0      2022  28,671 km  feb _2023         2184 cc
# ...

# %%
df.isnull()
# Out:
#    CRA_NAME  BRAND  PRICE    EMI  FUEL_TYPE  MAKE YEAR  KM DRIVEN  REG YEAR  \
# 0     False  False  False  False      False      False      False     False
# 1     False  False  False  False      False      False      False     False
# 2     False  False  False  False      False      False      False      True
# 3     False  False  False  False      False      False      False     False
# 4     False  False  False  False      False      False      False      True
# 5     False  False  False  False      False      False      False     False
# 6     False  False  False  False      False      False      False      True
# 7     False  False  False  False      False      False      False      True
# 8     False  False  False  False      False      False      False      True
# 9     False  False  False  False      False      False      False      True
#
#    ENGINE CAPACITY  INSURANCE  REG NUMBER  SPARE KEY  OWNER SHIP  COLOR
# ...

# %%
df.fillna(0)
# Out:
#                 CRA_NAME     BRAND       PRICE               EMI FUEL_TYPE  \
# 0  XUV700 AX3 D MT 5 STR  Mahindra   15.12Lakh      28,780/month    Diesel
# 1         BOLERO NEO N10  Mahindra  10.57 Lakh      20,119/month    Diesel
# 2        XUV700 AX 7 STR  Mahindra  23.25 Lakh  41,846/starts at    Petrol
# 3   XUV700 AX 5 MT 5 STR  Mahindra  18.65 Lakh  33,566/starts at    Diesel
# 4     XUV700 MX MT 5 STR  Mahindra   15.2 Lakh  27,357/starts at    Petrol
# 5    Scorpio Z8 AT 7 STR  Mahindra  20.75 Lakh  37,346/starts at    Petrol
# 6   XUV700 AX 3 MT 5 STR  Mahindra     16 Lakh  28,797/starts at    Petrol
# 7     XUV700 MX MT 5 STR  Mahindra   14.9 Lakh  26,817/starts at    Diesel
# 8              BOLERO N8   Mhindra   9.25 Lakh  16,648/starts at    Diesel
# 9          XUV300 1.5 W6   Mhindra   9.75 Lakh  17,548/starts at    Diesel
#
#   MAKE YEAR  KM DRIVEN   REG YEAR ENGINE CAPACITY  \
# 0      2022  28,671 km  feb _2023         2184 cc
# ...

# %%
df.dtypes
# Out:
# CRA_NAME           object
# BRAND              object
# PRICE              object
# EMI                object
# FUEL_TYPE          object
# MAKE YEAR          object
# KM DRIVEN          object
# REG YEAR           object
# ENGINE CAPACITY    object
# INSURANCE          object
# REG NUMBER         object
# SPARE KEY          object
# OWNER SHIP         object
# COLOR              object
# dtype: object

# %%
price_lst=df[['PRICE']]
print(price_lst)
# Out:
#         PRICE
# 0   15.12Lakh
# 1  10.57 Lakh
# 2  23.25 Lakh
# 3  18.65 Lakh
# 4   15.2 Lakh
# 5  20.75 Lakh
# 6     16 Lakh
# 7   14.9 Lakh
# 8   9.25 Lakh
# 9   9.75 Lakh

# %%
car_names_lst=df[['CRA_NAME']]
print(car_names_lst)
# Out:
#                 CRA_NAME
# 0  XUV700 AX3 D MT 5 STR
# 1         BOLERO NEO N10
# 2        XUV700 AX 7 STR
# 3   XUV700 AX 5 MT 5 STR
# 4     XUV700 MX MT 5 STR
# 5    Scorpio Z8 AT 7 STR
# 6   XUV700 AX 3 MT 5 STR
# 7     XUV700 MX MT 5 STR
# 8              BOLERO N8
# 9          XUV300 1.5 W6

# %%
used_km_lst=df[['KM DRIVEN']]
print(used_km_lst)
# Out:
#    KM DRIVEN
# 0  28,671 km
# 1  34,643 km
# 2  38,000 km
# 3  38,000 km
# 4   4,100 km
# 5   6,827 km
# 6  47,000 km
# 7  11,000 km
# 8  51,000 km
# 9  34,000 km

# %%
df['PRICE']=price_lst
price_lst
# Out:
#         PRICE
# 0   15.12Lakh
# 1  10.57 Lakh
# 2  23.25 Lakh
# 3  18.65 Lakh
# 4   15.2 Lakh
# 5  20.75 Lakh
# 6     16 Lakh
# 7   14.9 Lakh
# 8   9.25 Lakh
# 9   9.75 Lakh

# %%
df[['EMI']]
# Out:
#                 EMI
# 0      28,780/month
# 1      20,119/month
# 2  41,846/starts at
# 3  33,566/starts at
# 4  27,357/starts at
# 5  37,346/starts at
# 6  28,797/starts at
# 7  26,817/starts at
# 8  16,648/starts at
# 9  17,548/starts at

# %%
df["PRICE"]
# Out:
# 0     15.12Lakh
# 1    10.57 Lakh
# 2    23.25 Lakh
# 3    18.65 Lakh
# 4     15.2 Lakh
# 5    20.75 Lakh
# 6       16 Lakh
# 7     14.9 Lakh
# 8     9.25 Lakh
# 9     9.75 Lakh
# Name: PRICE, dtype: object

# %%
df['price_new']=df['PRICE'].map(lambda x: re.sub(r'\W+', '', x))
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df['price_new']=df['PRICE'].map(lambda x: re.sub(r'\W+', '', x))
#       2 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4539, in Series.map(self, arg, na_action)
#    4460 def map(
#    4461     self,
#    4462     arg: Callable | Mapping | Series,
#    4463     na_action: Literal["ignore"] | None = None,
#    4464 ) -> Series:
#    4465     """
#    4466     Map values of Series according to an input mapping or function.
#    4467
#    (...)
#    4537     dtype: object
#    4538     """
# -> 4539     new_values = self._map_values(arg, na_action=na_action)
#    4540     return self._constructor(new_values, index=self.index).__finalize__(
#    4541         self, method="map"
#    4542     )
#
# ...

# %%
brand=["Mahindra"]

# %%
df1=pd.DataFrame(brand,columns=['Brand_Name'])
df1
# Out:
#   Brand_Name
# 0   Mahindra

# %%
car=df.loc[:,"PRICE"]
price_lst=df["PRICE"]
df.price_lst.tolist()
print(price_lst)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 car=df.loc[:,"PRICE"]
#       2 price_lst=df["PRICE"]
# ----> 3 df.price_lst.tolist()
#       4 print(price_lst)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'price_lst'

# %%
car=df.loc[:,"PRICE"]
df['car']=price
print(price_lst)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 car=df.loc[:,"PRICE"]
# ----> 2 df['car']=price
#       3 print(price_lst)
#
# NameError: name 'price' is not defined

# %%
df['PRICE']=price_lst
price_lst
# Out:
# 0     15.12Lakh
# 1    10.57 Lakh
# 2    23.25 Lakh
# 3    18.65 Lakh
# 4     15.2 Lakh
# 5    20.75 Lakh
# 6       16 Lakh
# 7     14.9 Lakh
# 8     9.25 Lakh
# 9     9.75 Lakh
# Name: PRICE, dtype: object
